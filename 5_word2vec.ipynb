# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                    stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.862095
# Nearest to into: mal, dravidian, alligator, bassline, canned, hara, badlands, reactance,
# Nearest to can: abruzzo, wong, mohandas, geocache, kiel, mvs, quarterfinals, amputation,
# Nearest to his: certainly, often, dtp, mackay, consorts, trainer, kierkegaard, dualities,
# Nearest to three: forests, frege, solid, inserts, chisholm, broadcasting, xinjiang, establishing,
# Nearest to have: aids, tautology, liege, precedent, protectionist, breton, durant, thurgood,
# Nearest to are: gail, agreements, gathers, ventures, damper, delusions, fritz, panza,
# Nearest to however: vesa, oxidase, pines, electorates, lenz, harpoon, grossing, ibadi,
# Nearest to see: sparrows, epsilon, archdukes, kinase, mars, sisyphus, ploughing, uh,
# Nearest to with: sinope, nostrand, dole, nour, freeciv, row, sharply, dwelling,
# Nearest to may: celestial, minimized, decadence, northernmost, maharal, goofy, marion, disconnect,
# Nearest to united: characterised, litters, etymologies, admitting, myths, gases, mormons, impeachment,
# Nearest to history: sunni, prosper, outing, simone, drinking, carbonate, diffusing, humbert,
# Nearest to between: anastasio, charleroi, diagonals, stereo, amalthea, totalitarianism, closest, mauritians,
# Nearest to and: alkaloid, canals, congratulations, saltire, consistent, partitioning, geocache, autonomously,
# Nearest to people: feline, proudest, cutters, shrinks, incorporating, mackinac, tambourine, kale,
# Nearest to first: gloom, klondike, gaston, hutchins, slower, rapid, chapelle, sachs,
# Average loss at step 2000: 4.361741
# Average loss at step 4000: 3.861639
# Average loss at step 6000: 3.787749
# Average loss at step 8000: 3.689302
# Average loss at step 10000: 3.618746
# Nearest to into: from, pled, dravidian, badlands, bassline, single, recur, by,
# Nearest to can: could, may, would, geocache, ged, evaded, to, indicate,
# Nearest to his: their, the, its, s, her, internationalization, candid, ducks,
# Nearest to three: four, seven, five, eight, six, two, nine, zero,
# Nearest to have: had, has, be, are, were, beggars, finches, finland,
# Nearest to are: were, is, have, mcclure, was, byrd, stacking, biochemistry,
# Nearest to however: vesa, pines, conditioners, sa, bye, lenz, ward, lemy,
# Nearest to see: panasonic, orloff, cherries, mars, creationist, ultrasound, ploughing, tunable,
# Nearest to with: between, from, after, endocrinology, hindered, in, hartmann, soles,
# Nearest to may: would, can, must, shou, maharal, ergo, afloat, tsars,
# Nearest to united: litters, gases, characterised, subtype, inwardly, myths, roc, fragrant,
# Nearest to history: drinking, sunni, logo, prosper, humbert, madison, escalated, carolyn,
# Nearest to between: on, anastasio, stereo, with, diagonals, totalitarianism, comprehend, gay,
# Nearest to and: or, mama, which, samara, previews, s, he, katharina,
# Nearest to people: feline, proudest, collectives, mackinac, mop, kale, romain, muscles,
# Nearest to first: madhu, deuterocanonical, kune, moneypenny, invaluable, sachs, over, bendix,
# Average loss at step 12000: 3.603708
# Average loss at step 14000: 3.573945
# Average loss at step 16000: 3.409516
# Average loss at step 18000: 3.461688
# Average loss at step 20000: 3.534052
# Nearest to into: from, by, pled, dravidian, through, badlands, bassline, on,
# Nearest to can: may, could, would, will, should, must, might, ged,
# Nearest to his: their, her, its, contraception, the, dualities, internationalization, oakenfold,
# Nearest to three: four, two, six, five, seven, eight, zero, nine,
# Nearest to have: had, has, be, were, are, by, beggars, plunkett,
# Nearest to are: were, is, have, was, byrd, brava, been, uma,
# Nearest to however: but, that, vesa, although, which, fictional, heckler, there,
# Nearest to see: panasonic, rivest, cherries, airborne, knotted, orloff, dial, confidentiality,
# Nearest to with: after, between, by, in, hindered, internet, polities, sabina,
# Nearest to may: can, would, must, could, will, might, should, afloat,
# Nearest to united: litters, gases, characterised, subtype, roc, privatised, myths, spark,
# Nearest to history: drinking, comintern, humbert, logo, escalated, telegrams, duckling, carinthia,
# Nearest to between: stereo, in, with, anastasio, on, following, wenham, totalitarianism,
# Nearest to and: or, in, but, at, aisles, edlin, voyaging, own,
# Nearest to people: proudest, collectives, feline, mackinac, sailplane, farmers, hallucinogens, inexact,
# Nearest to first: deuterocanonical, third, second, moneypenny, bendix, same, kune, invaluable,
# Average loss at step 22000: 3.502407
# Average loss at step 24000: 3.491517
# Average loss at step 26000: 3.480937
# Average loss at step 28000: 3.478061
# Average loss at step 30000: 3.506770
# Nearest to into: from, through, pled, upon, during, kanembu, geese, dravidian,
# Nearest to can: could, may, would, will, must, should, might, to,
# Nearest to his: their, her, its, the, s, sligo, contraception, my,
# Nearest to three: seven, five, four, eight, six, two, nine, zero,
# Nearest to have: had, has, are, be, were, previously, newsletter, having,
# Nearest to are: were, is, have, include, redding, these, thrower, be,
# Nearest to however: but, although, though, that, while, when, vesa, because,
# Nearest to see: list, rebellions, panasonic, nosferatu, accommodation, blows, knotted, cherries,
# Nearest to with: between, under, without, endocrinology, hindered, infatuated, sabina, nostrand,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to united: litters, characterised, subtype, privatised, myths, roc, fragrant, cody,
# Nearest to history: drinking, carinthia, comintern, humbert, escalated, zier, journal, unlimited,
# Nearest to between: with, stereo, on, from, totalitarianism, wenham, undetected, against,
# Nearest to and: or, who, in, but, cosmopolitan, from, sampras, rocking,
# Nearest to people: proudest, feline, mackinac, relegated, collectives, sailplane, jews, hallucinogens,
# Nearest to first: second, third, next, deuterocanonical, invaluable, same, fourth, beyond,
# Average loss at step 32000: 3.497772
# Average loss at step 34000: 3.494981
# Average loss at step 36000: 3.450487
# Average loss at step 38000: 3.303783
# Average loss at step 40000: 3.427674
# Nearest to into: through, from, pled, upon, kanembu, badlands, during, bassline,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to his: their, her, its, my, s, the, contraception, your,
# Nearest to three: two, four, seven, five, six, eight, nine, overflowing,
# Nearest to have: had, has, were, are, be, previously, having, perigee,
# Nearest to are: were, have, including, is, be, these, include, thrower,
# Nearest to however: but, although, that, though, while, which, and, it,
# Nearest to see: knotted, larry, known, list, panasonic, can, mellor, rebellions,
# Nearest to with: between, hindered, in, on, when, at, by, della,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to united: litters, privatised, fragrant, cody, isin, characterised, farina, spark,
# Nearest to history: zier, assurances, jacobus, humbert, comintern, journal, allowance, escalated,
# Nearest to between: stereo, with, totalitarianism, among, following, at, on, wenham,
# Nearest to and: or, including, but, japanese, in, indepth, like, while,
# Nearest to people: xie, collectives, feline, mackinac, proudest, lo, hallucinogens, paleolithic,
# Nearest to first: second, next, last, third, invaluable, fourth, deuterocanonical, same,
# Average loss at step 42000: 3.434528
# Average loss at step 44000: 3.455584
# Average loss at step 46000: 3.445002
# Average loss at step 48000: 3.359584
# Average loss at step 50000: 3.380122
# Nearest to into: through, from, pled, badlands, within, during, on, bassline,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to his: their, her, its, my, chromite, the, your, tenniel,
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to have: had, has, were, are, be, having, argumentative, previously,
# Nearest to are: were, have, is, these, include, be, brava, thrower,
# Nearest to however: but, although, that, while, though, which, when, and,
# Nearest to see: list, debit, include, intolerable, seize, mellor, tvs, rebellions,
# Nearest to with: between, sabina, endocrinology, impromptu, nour, suitors, calves, banquets,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to united: litters, isin, privatised, fragrant, liberals, castlereagh, prophetess, cody,
# Nearest to history: humbert, assurances, taxation, zier, alam, breakdowns, property, majority,
# Nearest to between: with, stereo, among, in, from, through, following, frozen,
# Nearest to and: or, but, while, than, in, however, including, housework,
# Nearest to people: xie, jews, men, hallucinogens, feline, collectives, families, protested,
# Nearest to first: second, next, last, third, mid, same, incumbents, shelf,
# Average loss at step 52000: 3.438258
# Average loss at step 54000: 3.425088
# Average loss at step 56000: 3.437761
# Average loss at step 58000: 3.393342
# Average loss at step 60000: 3.395272
# Nearest to into: through, from, pled, within, mentats, in, badlands, dravidian,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to his: her, their, its, my, your, our, the, malign,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to have: had, has, were, are, be, having, include, previously,
# Nearest to are: were, is, have, these, include, those, brava, including,
# Nearest to however: but, although, though, that, while, which, really, lecturers,
# Nearest to see: list, include, references, but, can, tvs, mellor, panasonic,
# Nearest to with: between, sabina, when, della, suitors, mandating, cleveland, including,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to united: litters, isin, castlereagh, fragrant, privatised, germans, liberals, riaa,
# Nearest to history: demographics, property, humbert, list, jacobus, umm, zier, buildings,
# Nearest to between: with, among, stereo, over, in, through, simpler, following,
# Nearest to and: or, but, including, graziani, senescence, deductive, while, although,
# Nearest to people: jews, xie, men, collectives, feline, women, hallucinogens, mackinac,
# Nearest to first: second, last, next, third, final, only, same, fourth,
# Average loss at step 62000: 3.237547
# Average loss at step 64000: 3.254479
# Average loss at step 66000: 3.403250
# Average loss at step 68000: 3.392928
# Average loss at step 70000: 3.358342
# Nearest to into: through, from, pled, within, mentats, bassline, mogul, dravidian,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to his: her, their, its, my, your, the, our, sligo,
# Nearest to three: five, six, four, two, seven, eight, nine, zero,
# Nearest to have: had, has, were, are, include, be, contain, having,
# Nearest to are: were, is, have, include, although, these, be, including,
# Nearest to however: but, although, though, while, that, really, where, when,
# Nearest to see: include, list, but, rationalize, can, including, vogel, and,
# Nearest to with: between, sabina, infatuated, parva, sixes, della, hartmann, widths,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to united: litters, farina, minimizing, isin, greatest, blackout, germans, thyssen,
# Nearest to history: list, humbert, expression, goals, period, leader, collagen, taxation,
# Nearest to between: among, with, stereo, from, through, in, algal, diagonals,
# Nearest to and: or, including, senescence, which, like, but, while, facie,
# Nearest to people: men, women, jews, xie, families, feline, children, students,
# Nearest to first: second, last, next, third, final, same, fourth, bendix,
# Average loss at step 72000: 3.369872
# Average loss at step 74000: 3.348737
# Average loss at step 76000: 3.322759
# Average loss at step 78000: 3.348141
# Average loss at step 80000: 3.379884
# Nearest to into: through, from, within, pled, initial, sachet, in, erlang,
# Nearest to can: could, will, may, would, must, might, cannot, should,
# Nearest to his: her, their, its, my, your, our, sligo, banzer,
# Nearest to three: six, five, four, seven, eight, two, nine, zero,
# Nearest to have: had, has, are, were, include, be, farkas, having,
# Nearest to are: were, have, include, is, although, including, those, these,
# Nearest to however: although, but, though, while, that, nourishment, where, they,
# Nearest to see: include, list, but, mellor, refers, known, includes, references,
# Nearest to with: hindered, between, sabina, through, into, mandating, infatuated, banquets,
# Nearest to may: can, could, would, will, must, might, should, cannot,
# Nearest to united: litters, minimizing, blackout, mired, ectopic, isin, farina, germans,
# Nearest to history: list, goals, alam, lignite, catharism, philosophy, ecoregions, humbert,
# Nearest to between: among, stereo, with, within, through, over, around, following,
# Nearest to and: or, but, while, including, tris, waive, cordless, than,
# Nearest to people: men, jews, women, students, children, xie, families, collectives,
# Nearest to first: second, last, next, third, same, fourth, final, finish,
# Average loss at step 82000: 3.401104
# Average loss at step 84000: 3.408081
# Average loss at step 86000: 3.387443
# Average loss at step 88000: 3.350397
# Average loss at step 90000: 3.364046
# Nearest to into: through, from, pled, under, mentats, with, initial, erlang,
# Nearest to can: could, will, may, would, must, might, cannot, should,
# Nearest to his: her, their, its, my, your, our, the, sligo,
# Nearest to three: four, five, two, seven, eight, six, zero, nine,
# Nearest to have: had, has, were, are, include, be, having, require,
# Nearest to are: were, include, is, have, these, although, contain, scabbard,
# Nearest to however: but, although, though, that, while, nourishment, and, especially,
# Nearest to see: list, include, references, rationalize, refers, includes, seize, mellor,
# Nearest to with: between, mandating, by, into, sabina, impromptu, bit, hindered,
# Nearest to may: could, can, would, should, must, might, will, cannot,
# Nearest to united: blackout, mired, germans, minimizing, litters, greatest, isin, farina,
# Nearest to history: list, philosophy, majority, humbert, goals, ecoregions, thc, catharism,
# Nearest to between: among, within, with, stereo, through, over, around, against,
# Nearest to and: or, but, while, including, lex, deductive, however, through,
# Nearest to people: children, women, men, xie, students, jews, mackinac, evolving,
# Nearest to first: second, last, next, third, final, same, originally, fourth,
# Average loss at step 92000: 3.398582
# Average loss at step 94000: 3.252636
# Average loss at step 96000: 3.351206
# Average loss at step 98000: 3.244315
# Average loss at step 100000: 3.355131
# Nearest to into: through, from, within, pled, mentats, under, with, kanembu,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to his: her, their, your, my, our, its, the, sligo,
# Nearest to three: four, five, eight, six, two, seven, zero, nine,
# Nearest to have: had, has, are, were, include, be, having, provide,
# Nearest to are: were, have, include, those, be, is, these, although,
# Nearest to however: although, but, that, though, while, californians, which, especially,
# Nearest to see: list, references, refers, includes, include, materialists, chelmsford, iambic,
# Nearest to with: between, infatuated, including, sabina, into, impromptu, rask, unreliable,
# Nearest to may: can, could, should, would, might, must, will, cannot,
# Nearest to united: blackout, minimizing, litters, germans, mired, democratic, farina, credibility,
# Nearest to history: list, cantonese, ecoregions, collagen, confidentiality, philosophy, humbert, hermitage,
# Nearest to between: among, with, stereo, over, within, plundering, through, frozen,
# Nearest to and: but, or, although, while, sura, including, to, cheering,
# Nearest to people: children, students, men, women, jews, players, families, xie,
# Nearest to first: second, last, next, third, fourth, final, same, finish,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
import matplotlib
# %matplotlib inline
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
import pdb
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  context_size = 2 * skip_window
  assert batch_size % context_size == 0
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ context target context ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // context_size):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    labels[i, 0] = buffer[target]
    for j in range(context_size):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * context_size + j] = buffer[target]
      
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#     labels: ['originated', 'as', 'a', 'term', 'term', 'as', 'of', 'a']
#
# with skip_window = 2:
#     batch: ['anarchism', 'term', 'originated', 'a', 'as', 'originated', 'term', 'of']
#     labels: ['as', 'a', 'originated', 'a', 'term', 'as', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                    stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, 
                                                   train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.802043
# Nearest to also: commence, polemics, cholesterol, freed, goods, exhausted, wields, wolsey,
# Nearest to they: abl, chronologically, expressway, contract, pryor, relevant, batman, exemplifies,
# Nearest to from: omit, rack, francophones, voight, keane, longed, homomorphism, lawmaking,
# Nearest to world: global, marathon, inhumane, koreans, mjf, crisis, tips, lamas,
# Nearest to years: futurism, celestine, armored, synergy, prostitute, statistics, toppled, tian,
# Nearest to two: ammonia, charter, preserve, autres, disavow, illuminating, monte, temporal,
# Nearest to as: sampa, deflecting, anthropology, hypoxia, suite, illustrating, ztt, dreamlike,
# Nearest to six: anaesthesia, igneous, turkmen, margulis, odyssey, imprisoned, mainstay, jesus,
# Nearest to first: palatalization, conductors, courtney, fuelled, ruben, altruists, walters, pointer,
# Nearest to use: promiscuous, childe, marquette, canceling, outskirts, smaller, papacy, ordinations,
# Nearest to would: semaphore, awful, jo, austronesian, bouchard, codex, creature, sidemen,
# Nearest to these: amish, koenigsegg, cia, aslan, notwithstanding, house, yod, keno,
# Nearest to have: jp, heliopause, proliferated, join, talmud, muons, tabled, rasputin,
# Nearest to than: tabor, cn, monsieur, theropods, macht, adamantly, gilles, samson,
# Nearest to state: petitioned, odore, berlin, sling, qatar, mashed, mail, nonempty,
# Nearest to will: brindisi, luc, treatises, leigh, ankle, supply, heterozygous, nerve,
# Average loss at step 2000: 4.754373
# Average loss at step 4000: 4.298581
# Average loss at step 6000: 4.228050
# Average loss at step 8000: 4.171713
# Average loss at step 10000: 4.107133
# Nearest to also: as, swallowed, in, term, avant, or, gingrich, plough,
# Nearest to they: contract, arranged, though, other, pryor, yell, chronologically, expressway,
# Nearest to from: as, an, that, by, on, or, to, day,
# Nearest to world: inhumane, paran, marathon, crisis, global, join, palo, aldiss,
# Nearest to years: futurism, statistics, prostitute, armored, depends, intuitive, burgundian, toppled,
# Nearest to two: nine, eight, six, zero, one, three, four, seven,
# Nearest to as: that, or, an, to, are, from, is, for,
# Nearest to six: nine, seven, four, three, eight, one, five, two,
# Nearest to first: fuelled, palatalization, conductors, ambivalence, pointer, walters, surgeon, electronegativity,
# Nearest to use: smaller, childe, lincoln, sometime, stout, understand, marquette, stories,
# Nearest to would: elegans, semaphore, austronesian, awful, am, science, bouchard, cosa,
# Nearest to these: keno, koenigsegg, proto, cia, needless, still, alfonso, house,
# Nearest to have: are, morphisms, talmud, jp, join, separate, on, restatement,
# Nearest to than: cn, tabor, ktav, ter, adamantly, yat, gross, valium,
# Nearest to state: berlin, mail, petty, street, nonempty, odore, sling, rhyme,
# Nearest to will: brindisi, luc, nerve, treatises, supply, followed, clear, oe,
# Average loss at step 12000: 4.092723
# Average loss at step 14000: 4.063203
# Average loss at step 16000: 3.951340
# Average loss at step 18000: 4.008939
# Average loss at step 20000: 4.076778
# Nearest to also: an, with, or, for, to, s, are, that,
# Nearest to they: be, but, with, which, by, this, their, as,
# Nearest to from: to, a, s, the, it, this, an, can,
# Nearest to world: inhumane, paran, join, haile, aldiss, komodo, moines, crisis,
# Nearest to years: statistics, futurism, prostitute, armored, depends, magazines, intuitive, parted,
# Nearest to two: four, one, three, five, six, nine, zero, eight,
# Nearest to as: it, are, that, is, to, a, an, by,
# Nearest to six: five, eight, seven, three, one, two, nine, four,
# Nearest to first: was, an, walters, dates, after, iqs, occasional, alpha,
# Nearest to use: sometime, smaller, virtual, this, lincoln, herculaneum, corrupts, backlight,
# Nearest to would: am, that, be, coed, science, to, cosa, tsar,
# Nearest to these: which, this, keno, it, gbase, we, showing, drawer,
# Nearest to have: this, it, with, which, an, be, to, are,
# Nearest to than: an, a, by, yat, have, cn, ktav, larvae,
# Nearest to state: street, mail, berlin, sling, spectrometer, phonemes, debauchery, retardation,
# Nearest to will: brindisi, luc, nerve, yury, dissolve, ran, ankle, disperse,
# Average loss at step 22000: 4.016978
# Average loss at step 24000: 4.041757
# Average loss at step 26000: 4.045294
# Average loss at step 28000: 4.011076
# Average loss at step 30000: 4.066356
# Nearest to also: or, used, for, their, that, not, some, is,
# Nearest to they: their, some, to, such, not, that, or, of,
# Nearest to from: by, which, first, s, of, the, in, on,
# Nearest to world: join, to, inhumane, paran, unattested, community, mrs, komodo,
# Nearest to years: statistics, with, was, futurism, prostitute, suede, parted, armored,
# Nearest to two: zero, three, five, four, six, eight, one, seven,
# Nearest to as: and, for, the, in, of, to, has, on,
# Nearest to six: seven, five, three, zero, one, eight, four, two,
# Nearest to first: from, s, was, after, for, during, bebe, on,
# Nearest to use: sometime, more, stout, cricetulus, smaller, understand, glowing, atomists,
# Nearest to would: tsar, am, intrinsically, had, patton, beazley, trump, coed,
# Nearest to these: which, such, are, not, an, have, other, or,
# Nearest to have: such, or, be, has, but, for, most, an,
# Nearest to than: more, not, their, time, yat, cavour, cn, or,
# Nearest to state: berlin, street, debauchery, nonempty, are, influenced, mail, buson,
# Nearest to will: luc, brindisi, nerve, so, disperse, ankle, ran, yury,
# Average loss at step 32000: 4.053368
# Average loss at step 34000: 4.068407
# Average loss at step 36000: 4.039660
# Average loss at step 38000: 3.950531
# Average loss at step 40000: 3.987084
# Nearest to also: an, as, used, a, in, are, with, by,
# Nearest to they: their, an, with, not, also, if, some, such,
# Nearest to from: as, that, with, on, an, many, is, for,
# Nearest to world: caldera, community, during, under, boudica, global, mace, naphtali,
# Nearest to years: statistics, trains, futurism, expounded, parted, zubrin, prostitute, smooth,
# Nearest to two: six, five, zero, three, seven, four, nine, one,
# Nearest to as: which, or, and, also, with, from, by, in,
# Nearest to six: five, two, three, zero, seven, one, nine, eight,
# Nearest to first: was, s, an, by, from, after, he, during,
# Nearest to use: or, used, an, stout, sometime, cricetulus, not, this,
# Nearest to would: after, them, had, be, they, angolan, trump, himself,
# Nearest to these: such, middle, have, christiane, there, cache, many, which,
# Nearest to have: many, such, are, be, with, by, it, to,
# Nearest to than: more, number, be, if, over, to, an, for,
# Nearest to state: states, influenced, united, berlin, street, spectrometer, national, nonempty,
# Nearest to will: so, there, luc, nerve, brindisi, it, but, with,
# Average loss at step 42000: 4.010205
# Average loss at step 44000: 4.037220
# Average loss at step 46000: 4.032716
# Average loss at step 48000: 3.943485
# Average loss at step 50000: 3.987278
# Nearest to also: as, s, this, in, for, on, most, with,
# Nearest to they: this, to, as, have, which, for, but, would,
# Nearest to from: this, with, as, in, are, to, also, been,
# Nearest to world: global, slipknot, caldera, famous, aldiss, american, lepton, semitic,
# Nearest to years: statistics, were, had, trains, his, gore, relax, vci,
# Nearest to two: three, six, five, eight, four, one, zero, seven,
# Nearest to as: also, in, to, with, and, of, has, this,
# Nearest to six: seven, two, eight, five, three, nine, four, one,
# Nearest to first: was, she, during, century, th, but, he, six,
# Nearest to use: some, this, used, for, other, be, to, often,
# Nearest to would: had, they, tsar, after, he, however, with, for,
# Nearest to these: such, have, with, which, this, also, not, many,
# Nearest to have: with, these, not, more, this, when, be, which,
# Nearest to than: can, this, time, more, an, such, are, fortuitous,
# Nearest to state: states, by, spectrometer, in, national, street, buson, united,
# Nearest to will: so, be, that, have, can, there, some, not,
# Average loss at step 52000: 4.036724
# Average loss at step 54000: 4.036154
# Average loss at step 56000: 4.034811
# Average loss at step 58000: 4.026413
# Average loss at step 60000: 3.986969
# Nearest to also: such, to, are, with, some, has, and, for,
# Nearest to they: their, have, that, as, not, some, when, are,
# Nearest to from: it, have, is, that, and, to, in, this,
# Nearest to world: american, war, semitic, expenditures, incomplete, atheism, many, been,
# Nearest to years: trains, statistics, est, lith, remembered, prostitute, fanfiction, five,
# Nearest to two: zero, six, three, five, one, four, nine, seven,
# Nearest to as: that, to, are, in, most, and, have, such,
# Nearest to six: nine, four, eight, three, seven, one, two, five,
# Nearest to first: renowned, grand, on, farina, time, obstructed, mitigating, mohammad,
# Nearest to use: used, a, other, on, often, some, in, both,
# Nearest to would: had, over, after, however, was, that, they, time,
# Nearest to these: have, many, not, as, other, most, such, that,
# Nearest to have: they, that, as, most, these, their, other, to,
# Nearest to than: more, at, to, such, can, time, an, be,
# Nearest to state: states, spectrometer, buson, street, government, chanced, united, berlin,
# Nearest to will: so, that, a, when, not, be, sampa, or,
# Average loss at step 62000: 3.922429
# Average loss at step 64000: 3.945463
# Average loss at step 66000: 4.029505
# Average loss at step 68000: 3.999358
# Average loss at step 70000: 3.988410
# Nearest to also: many, as, such, mulhouse, other, or, an, some,
# Nearest to they: but, to, their, not, as, have, that, some,
# Nearest to from: between, UNK, in, and, with, into, is, or,
# Nearest to world: american, states, global, propto, rh, spanning, fida, detachment,
# Nearest to years: female, five, age, population, four, statistics, verdict, est,
# Nearest to two: three, zero, one, four, five, six, seven, nine,
# Nearest to as: have, or, be, is, some, not, by, which,
# Nearest to six: four, three, one, seven, five, eight, nine, two,
# Nearest to first: was, were, who, out, he, after, his, off,
# Nearest to use: of, used, or, are, other, in, to, the,
# Nearest to would: be, that, however, which, more, have, it, but,
# Nearest to these: in, such, some, of, be, that, more, and,
# Nearest to have: as, to, not, that, be, they, more, but,
# Nearest to than: be, or, that, such, as, with, to, and,
# Nearest to state: national, berlin, united, states, keralite, kenning, spectrometer, cardinals,
# Nearest to will: that, be, not, a, as, so, if, and,
# Average loss at step 72000: 3.968445
# Average loss at step 74000: 3.984012
# Average loss at step 76000: 3.924691
# Average loss at step 78000: 3.967208
# Average loss at step 80000: 4.015382
# Nearest to also: see, most, more, many, into, triage, known, exemplary,
# Nearest to they: their, have, them, with, were, nicene, more, only,
# Nearest to from: cola, conclude, two, scotia, five, east, cleef, zero,
# Nearest to world: while, as, has, however, states, semitic, but, fida,
# Nearest to years: age, hazlitt, being, flute, have, female, only, who,
# Nearest to two: four, five, three, zero, one, eight, seven, six,
# Nearest to as: with, more, and, be, world, well, are, americanized,
# Nearest to six: five, three, eight, seven, four, two, one, nine,
# Nearest to first: was, were, after, he, later, his, had, time,
# Nearest to use: used, can, be, are, these, or, more, often,
# Nearest to would: had, have, were, that, however, they, more, only,
# Nearest to these: be, although, some, however, many, may, into, while,
# Nearest to have: may, would, more, much, however, they, be, other,
# Nearest to than: be, that, have, more, other, are, there, cabral,
# Nearest to state: ties, tolerance, bless, united, debauchery, governor, british, rape,
# Nearest to will: if, be, may, when, so, but, can, similar,
# Average loss at step 82000: 4.033711
# Average loss at step 84000: 4.024842
# Average loss at step 86000: 4.007364
# Average loss at step 88000: 3.984150
# Average loss at step 90000: 4.011190
# Nearest to also: more, such, often, see, some, a, caspar, known,
# Nearest to they: their, irresistible, them, could, people, were, even, nicene,
# Nearest to from: UNK, of, modified, were, to, that, axis, sympathized,
# Nearest to world: detachment, while, global, semitic, fida, avatars, viceroyalty, spanning,
# Nearest to years: over, during, age, his, flute, only, hazlitt, population,
# Nearest to two: seven, zero, three, six, four, one, eight, five,
# Nearest to as: that, of, in, to, pows, for, and, have,
# Nearest to six: seven, four, eight, three, five, one, two, zero,
# Nearest to first: later, batasuna, solidified, zeppelin, mccain, outposts, were, an,
# Nearest to use: used, often, most, these, such, more, system, can,
# Nearest to would: had, that, were, have, when, more, to, which,
# Nearest to these: this, most, based, are, be, which, have, use,
# Nearest to have: more, than, would, often, are, most, only, much,
# Nearest to than: have, this, because, are, or, would, no, more,
# Nearest to state: states, united, governor, government, ties, papacy, reverse, excised,
# Nearest to will: be, that, so, can, if, even, may, most,
# Average loss at step 92000: 4.016048
# Average loss at step 94000: 3.937633
# Average loss at step 96000: 3.987295
# Average loss at step 98000: 3.908821
# Average loss at step 100000: 3.993920
# Nearest to also: by, has, on, most, an, are, see, many,
# Nearest to they: them, to, no, so, that, their, only, than,
# Nearest to from: for, of, bowler, gaels, shovel, in, as, them,
# Nearest to world: united, states, spanning, leno, haeckel, rainey, landforms, diarrhoea,
# Nearest to years: flute, age, population, braddock, readily, female, his, machining,
# Nearest to two: zero, three, five, four, six, one, eight, seven,
# Nearest to as: in, to, the, which, of, and, a, for,
# Nearest to six: seven, three, five, four, two, eight, zero, one,
# Nearest to first: later, his, was, by, oust, after, on, aum,
# Nearest to use: system, used, are, common, different, systems, with, such,
# Nearest to would: had, after, when, were, them, only, time, he,
# Nearest to these: different, based, have, some, considered, popular, often, many,
# Nearest to have: much, more, to, their, or, there, them, these,
# Nearest to than: this, are, system, only, cabral, each, they, so,
# Nearest to state: states, united, reverse, government, hydroponic, condition, college, stalemate,
# Nearest to will: if, so, up, can, no, not, through, may,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
import matplotlib
# %matplotlib inline
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
